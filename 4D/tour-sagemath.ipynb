# %%
3+5
# Out:
# 8

# %%
P = polytopes.simplex(4)
P.plot()
# Out:
# Graphics3d Object

# %%
P = polytopes.hypercube(4)
P.plot()
# Out:
# Graphics3d Object

# %%
P = polytopes.cross_polytope(4)
P.plot()
# Out:
# Graphics3d Object

# %%
P = polytopes.twenty_four_cell()
P.plot()
# Out:
# Graphics3d Object

# %%
P = polytopes.one_hundred_twenty_cell()
P.plot()
# Out:
# Graphics3d Object

# %%
P = polytopes.six_hundred_cell()
P.plot()
# Out:
# Graphics3d Object
